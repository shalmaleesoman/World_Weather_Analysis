# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import random
from citipy import citipy
from config3 import weather_api_key
from config3 import g_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 583

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | port-gentil
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | muros
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | hualmay
# Processing Record 7 of Set 1 | port hedland
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | akureyri
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | berlevag
# Processing Record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | bhadrachalam
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | broome
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | kieta
# Processing Record 24 of Set 1 | espinosa
# Processing Record 25 of Set 1 | mount gambier
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | liberia
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | lavrentiya
# Processing Record 31 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 32 of Set 1 | evensk
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | lasa
# Processing Record 35 of Set 1 | mareeba
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | hewitt
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | mykolayiv
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | turukhansk
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | hovd
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | caraquet
# Processing Record 4 of Set 2 | koraput
# Processing Record 5 of Set 2 | celestun
# Processing Record 6 of Set 2 | mantua
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | kargil
# Processing Record 10 of Set 2 | anahuac
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | rosarito
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | pacific grove
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | margate
# Processing Record 18 of Set 2 | uddevalla
# Processing Record 19 of Set 2 | saint anthony
# Processing Record 20 of Set 2 | vila franca do campo
# Processing Record 21 of Set 2 | brindisi
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | ayan
# Processing Record 29 of Set 2 | huarmey
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 2 | votkinsk
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | kropotkin
# Processing Record 35 of Set 2 | valparai
# Processing Record 36 of Set 2 | andrews
# Processing Record 37 of Set 2 | bilma
# Processing Record 38 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | kutum
# Processing Record 42 of Set 2 | beian
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | opuwo
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | aklavik
# Processing Record 48 of Set 2 | aiquile
# Processing Record 49 of Set 2 | antalaha
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | dabat
# Processing Record 4 of Set 3 | nelipyno
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | kamenka
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | barreirinhas
# Processing Record 11 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | menongue
# Processing Record 16 of Set 3 | najran
# Processing Record 17 of Set 3 | hambantota
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | guerrero negro
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | leshan
# Processing Record 22 of Set 3 | san patricio
# Processing Record 23 of Set 3 | pangai
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | thinadhoo
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | beira
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | arlit
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | klyuchevskiy
# Processing Record 36 of Set 3 | srednekolymsk
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | walvis bay
# Processing Record 39 of Set 3 | oktyabrskoye
# Processing Record 40 of Set 3 | jalu
# Processing Record 41 of Set 3 | maxixe
# Processing Record 42 of Set 3 | shu
# Processing Record 43 of Set 3 | asyut
# Processing Record 44 of Set 3 | butterworth
# Processing Record 45 of Set 3 | miri
# Processing Record 46 of Set 3 | obsharovka
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | raga
# Processing Record 49 of Set 3 | broken hill
# Processing Record 50 of Set 3 | yining
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | port-cartier
# Processing Record 5 of Set 4 | verkhnevilyuysk
# Processing Record 6 of Set 4 | hilo
# Processing Record 7 of Set 4 | krasnoselkup
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | bac lieu
# Processing Record 10 of Set 4 | stromness
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | nuuk
# Processing Record 13 of Set 4 | chimore
# Processing Record 14 of Set 4 | shimoda
# Processing Record 15 of Set 4 | svetlogorsk
# Processing Record 16 of Set 4 | ossora
# Processing Record 17 of Set 4 | saint-louis
# Processing Record 18 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 4 | sept-iles
# Processing Record 20 of Set 4 | pitimbu
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | port alfred
# Processing Record 23 of Set 4 | canala
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | kinlochleven
# Processing Record 26 of Set 4 | vanavara
# Processing Record 27 of Set 4 | imeni poliny osipenko
# Processing Record 28 of Set 4 | westport
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | aginskoye
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | hukuntsi
# Processing Record 33 of Set 4 | mora
# Processing Record 34 of Set 4 | mehamn
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | saint-joseph
# Processing Record 39 of Set 4 | manaure
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | cuamba
# Processing Record 43 of Set 4 | khatanga
# Processing Record 44 of Set 4 | inuvik
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | maryville
# Processing Record 48 of Set 4 | ati
# Processing Record 49 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 4 | salalah
# Processing Record 1 of Set 5 | komsomolskiy
# Processing Record 2 of Set 5 | raymond terrace
# Processing Record 3 of Set 5 | ambilobe
# Processing Record 4 of Set 5 | faanui
# Processing Record 5 of Set 5 | roseburg
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | bodaybo
# Processing Record 8 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | barsovo
# Processing Record 11 of Set 5 | oussouye
# Processing Record 12 of Set 5 | dubbo
# Processing Record 13 of Set 5 | adrar
# Processing Record 14 of Set 5 | kaoma
# Processing Record 15 of Set 5 | pangnirtung
# Processing Record 16 of Set 5 | roma
# Processing Record 17 of Set 5 | beaverlodge
# Processing Record 18 of Set 5 | noyabrsk
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 5 | boundiali
# Processing Record 22 of Set 5 | sendafa
# Processing Record 23 of Set 5 | yulara
# Processing Record 24 of Set 5 | haines junction
# Processing Record 25 of Set 5 | henties bay
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | kokkola
# Processing Record 28 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 5 | byron bay
# Processing Record 30 of Set 5 | sembe
# Processing Record 31 of Set 5 | hagere hiywet
# Processing Record 32 of Set 5 | khash
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | merrill
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | poum
# Processing Record 37 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 5 | raudeberg
# Processing Record 39 of Set 5 | kazerun
# Processing Record 40 of Set 5 | oranjestad
# Processing Record 41 of Set 5 | dickinson
# Processing Record 42 of Set 5 | shar
# Processing Record 43 of Set 5 | kaduy
# Processing Record 44 of Set 5 | acarau
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | east london
# Processing Record 48 of Set 5 | buala
# Processing Record 49 of Set 5 | okmulgee
# Processing Record 50 of Set 5 | bay roberts
# Processing Record 1 of Set 6 | ketchikan
# Processing Record 2 of Set 6 | nishiwaki
# Processing Record 3 of Set 6 | puerto escondido
# Processing Record 4 of Set 6 | cherskiy
# Processing Record 5 of Set 6 | bathsheba
# Processing Record 6 of Set 6 | parbatipur
# Processing Record 7 of Set 6 | khandyga
# Processing Record 8 of Set 6 | fort nelson
# Processing Record 9 of Set 6 | dukat
# Processing Record 10 of Set 6 | gewane
# Processing Record 11 of Set 6 | kharan
# Processing Record 12 of Set 6 | severo-kurilsk
# Processing Record 13 of Set 6 | dubovskoye
# Processing Record 14 of Set 6 | upernavik
# Processing Record 15 of Set 6 | san cristobal
# Processing Record 16 of Set 6 | pengcheng
# Processing Record 17 of Set 6 | manggar
# Processing Record 18 of Set 6 | amapa
# Processing Record 19 of Set 6 | buraydah
# Processing Record 20 of Set 6 | sakaiminato
# Processing Record 21 of Set 6 | koumac
# Processing Record 22 of Set 6 | volterra
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | san vicente
# Processing Record 25 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | taltal
# Processing Record 28 of Set 6 | benjamin aceval
# Processing Record 29 of Set 6 | farim
# Processing Record 30 of Set 6 | cortez
# Processing Record 31 of Set 6 | lompoc
# Processing Record 32 of Set 6 | sola
# Processing Record 33 of Set 6 | spirit river
# Processing Record 34 of Set 6 | tessalit
# Processing Record 35 of Set 6 | la palma
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | manjeshwar
# Processing Record 39 of Set 6 | iqaluit
# Processing Record 40 of Set 6 | dzhebariki-khaya
# Processing Record 41 of Set 6 | port elizabeth
# Processing Record 42 of Set 6 | yabrud
# Processing Record 43 of Set 6 | ler
# Processing Record 44 of Set 6 | sena madureira
# Processing Record 45 of Set 6 | gogrial
# Processing Record 46 of Set 6 | mahina
# Processing Record 47 of Set 6 | humaita
# Processing Record 48 of Set 6 | abu dhabi
# Processing Record 49 of Set 6 | helong
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | bairiki
# Processing Record 2 of Set 7 | vilcun
# Processing Record 3 of Set 7 | calbayog
# Processing Record 4 of Set 7 | alyangula
# Processing Record 5 of Set 7 | atar
# Processing Record 6 of Set 7 | muravlenko
# Processing Record 7 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 7 | mercedes
# Processing Record 9 of Set 7 | mackay
# Processing Record 10 of Set 7 | hami
# Processing Record 11 of Set 7 | sivaki
# Processing Record 12 of Set 7 | narsaq
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | norman wells
# Processing Record 16 of Set 7 | solnechnyy
# Processing Record 17 of Set 7 | san buenaventura
# Processing Record 18 of Set 7 | bheramara
# Processing Record 19 of Set 7 | cepu
# Processing Record 20 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 21 of Set 7 | minuri
# Processing Record 22 of Set 7 | vostok
# Processing Record 23 of Set 7 | shurugwi
# Processing Record 24 of Set 7 | nome
# Processing Record 25 of Set 7 | mochudi
# Processing Record 26 of Set 7 | khorramshahr
# Processing Record 27 of Set 7 | bismarck
# Processing Record 28 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 7 | pavino
# Processing Record 30 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 7 | pierre
# Processing Record 32 of Set 7 | bud
# Processing Record 33 of Set 7 | nikolayevsk-na-amure
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | mahon
# Processing Record 36 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 7 | qasigiannguit
# Processing Record 38 of Set 7 | campbell river
# Processing Record 39 of Set 7 | fernandez
# Processing Record 40 of Set 7 | angoram
# Processing Record 41 of Set 7 | sao joao da barra
# Processing Record 42 of Set 7 | zhigansk
# Processing Record 43 of Set 7 | yar-sale
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 7 | jiehu
# Processing Record 47 of Set 7 | eyl
# Processing Record 48 of Set 7 | moron
# Processing Record 49 of Set 7 | shelburne
# Processing Record 50 of Set 7 | victor harbor
# Processing Record 1 of Set 8 | sartell
# Processing Record 2 of Set 8 | ongandjera
# Processing Record 3 of Set 8 | craig
# Processing Record 4 of Set 8 | tiksi
# Processing Record 5 of Set 8 | honningsvag
# Processing Record 6 of Set 8 | zlitan
# Processing Record 7 of Set 8 | elko
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | russell
# Processing Record 10 of Set 8 | waipawa
# Processing Record 11 of Set 8 | emerald
# Processing Record 12 of Set 8 | havoysund
# Processing Record 13 of Set 8 | rantepao
# Processing Record 14 of Set 8 | namibe
# Processing Record 15 of Set 8 | eureka
# Processing Record 16 of Set 8 | ames
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | hanmer springs
# Processing Record 19 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 8 | ouesso
# Processing Record 21 of Set 8 | half moon bay
# Processing Record 22 of Set 8 | cayenne
# Processing Record 23 of Set 8 | ndende
# Processing Record 24 of Set 8 | waingapu
# Processing Record 25 of Set 8 | mana
# Processing Record 26 of Set 8 | san andres
# Processing Record 27 of Set 8 | oromocto
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | shache
# Processing Record 30 of Set 8 | conakry
# Processing Record 31 of Set 8 | turayf
# Processing Record 32 of Set 8 | karatau
# Processing Record 33 of Set 8 | assiniboia
# Processing Record 34 of Set 8 | phnum penh
# City not found. Skipping...
# Processing Record 35 of Set 8 | sambava
# Processing Record 36 of Set 8 | svetlaya
# Processing Record 37 of Set 8 | carutapera
# Processing Record 38 of Set 8 | rantauprapat
# Processing Record 39 of Set 8 | lakes entrance
# Processing Record 40 of Set 8 | yantzaza
# Processing Record 41 of Set 8 | dingle
# Processing Record 42 of Set 8 | batticaloa
# Processing Record 43 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 44 of Set 8 | hosakote
# Processing Record 45 of Set 8 | saint-pierre
# Processing Record 46 of Set 8 | aykhal
# Processing Record 47 of Set 8 | alice springs
# Processing Record 48 of Set 8 | kolokani
# Processing Record 49 of Set 8 | acapulco
# Processing Record 50 of Set 8 | katherine
# Processing Record 1 of Set 9 | teknaf
# Processing Record 2 of Set 9 | sassandra
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | trebinje
# Processing Record 5 of Set 9 | teya
# Processing Record 6 of Set 9 | nivala
# Processing Record 7 of Set 9 | abu kamal
# Processing Record 8 of Set 9 | san quintin
# Processing Record 9 of Set 9 | champasak
# Processing Record 10 of Set 9 | soubre
# Processing Record 11 of Set 9 | puerto el triunfo
# Processing Record 12 of Set 9 | fairview
# Processing Record 13 of Set 9 | neuquen
# Processing Record 14 of Set 9 | amarkantak
# Processing Record 15 of Set 9 | niihama
# Processing Record 16 of Set 9 | hoa binh
# Processing Record 17 of Set 9 | cascas
# Processing Record 18 of Set 9 | aqtobe
# Processing Record 19 of Set 9 | kalengwa
# Processing Record 20 of Set 9 | luwingu
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | karratha
# Processing Record 23 of Set 9 | brae
# Processing Record 24 of Set 9 | san policarpo
# Processing Record 25 of Set 9 | nortelandia
# Processing Record 26 of Set 9 | burnie
# Processing Record 27 of Set 9 | takoradi
# Processing Record 28 of Set 9 | asau
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | lethem
# Processing Record 31 of Set 9 | jacareacanga
# Processing Record 32 of Set 9 | gambela
# Processing Record 33 of Set 9 | esmeraldas
# Processing Record 34 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 9 | vilhena
# Processing Record 36 of Set 9 | tual
# Processing Record 37 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 9 | anadyr
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 9 | luderitz
# Processing Record 43 of Set 9 | batagay
# Processing Record 44 of Set 9 | lata
# Processing Record 45 of Set 9 | saint-augustin
# Processing Record 46 of Set 9 | tila
# Processing Record 47 of Set 9 | vanimo
# Processing Record 48 of Set 9 | bubaque
# Processing Record 49 of Set 9 | tuatapere
# Processing Record 50 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 10 | iskateley
# Processing Record 2 of Set 10 | araouane
# Processing Record 3 of Set 10 | labuhan
# Processing Record 4 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 10 | misratah
# Processing Record 6 of Set 10 | bahir dar
# Processing Record 7 of Set 10 | hofn
# Processing Record 8 of Set 10 | mugur-aksy
# Processing Record 9 of Set 10 | erenhot
# Processing Record 10 of Set 10 | coos bay
# Processing Record 11 of Set 10 | altay
# Processing Record 12 of Set 10 | amazar
# Processing Record 13 of Set 10 | benjamin constant
# Processing Record 14 of Set 10 | tunxi
# City not found. Skipping...
# Processing Record 15 of Set 10 | akdepe
# Processing Record 16 of Set 10 | san carlos sija
# Processing Record 17 of Set 10 | bowen
# Processing Record 18 of Set 10 | saint-francois
# Processing Record 19 of Set 10 | palmeiras de goias
# Processing Record 20 of Set 10 | jertih
# Processing Record 21 of Set 10 | egvekinot
# Processing Record 22 of Set 10 | copacabana
# Processing Record 23 of Set 10 | jinxiang
# Processing Record 24 of Set 10 | balad
# Processing Record 25 of Set 10 | magadan
# Processing Record 26 of Set 10 | nampula
# Processing Record 27 of Set 10 | la paz
# Processing Record 28 of Set 10 | zhengjiatun
# Processing Record 29 of Set 10 | marzuq
# Processing Record 30 of Set 10 | kazanka
# Processing Record 31 of Set 10 | chantada
# Processing Record 32 of Set 10 | mandera
# Processing Record 33 of Set 10 | port blair
# Processing Record 34 of Set 10 | fukue
# Processing Record 35 of Set 10 | brigantine
# Processing Record 36 of Set 10 | churapcha
# Processing Record 37 of Set 10 | prince rupert
# Processing Record 38 of Set 10 | sorland
# Processing Record 39 of Set 10 | gualeguay
# Processing Record 40 of Set 10 | floro
# Processing Record 41 of Set 10 | wahpeton
# Processing Record 42 of Set 10 | wanning
# Processing Record 43 of Set 10 | alindao
# Processing Record 44 of Set 10 | denpasar
# Processing Record 45 of Set 10 | karla
# Processing Record 46 of Set 10 | ust-tsilma
# Processing Record 47 of Set 10 | matara
# Processing Record 48 of Set 10 | puerto baquerizo moreno
# Processing Record 49 of Set 10 | lumeje
# Processing Record 50 of Set 10 | saint-georges
# Processing Record 1 of Set 11 | mabai
# Processing Record 2 of Set 11 | fortuna
# Processing Record 3 of Set 11 | pisco
# Processing Record 4 of Set 11 | buchanan
# Processing Record 5 of Set 11 | chulym
# Processing Record 6 of Set 11 | xiaoweizhai
# Processing Record 7 of Set 11 | kalat
# Processing Record 8 of Set 11 | imuris
# Processing Record 9 of Set 11 | capreol
# Processing Record 10 of Set 11 | gold coast
# Processing Record 11 of Set 11 | at-bashi
# Processing Record 12 of Set 11 | huacho
# Processing Record 13 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 11 | sortavala
# Processing Record 15 of Set 11 | sile
# Processing Record 16 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 11 | koslan
# Processing Record 18 of Set 11 | bogandinskiy
# Processing Record 19 of Set 11 | atherton
# Processing Record 20 of Set 11 | puerto narino
# Processing Record 21 of Set 11 | ulaanbaatar
# Processing Record 22 of Set 11 | moose factory
# Processing Record 23 of Set 11 | panguna
# Processing Record 24 of Set 11 | bako
# Processing Record 25 of Set 11 | kasongo-lunda
# Processing Record 26 of Set 11 | yeppoon
# Processing Record 27 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 11 | aksu
# Processing Record 29 of Set 11 | ilebo
# Processing Record 30 of Set 11 | jiamusi
# Processing Record 31 of Set 11 | saint-leu
# Processing Record 32 of Set 11 | baker city
# Processing Record 33 of Set 11 | dambulla
# Processing Record 34 of Set 11 | sivas
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | jumla
# Processing Record 37 of Set 11 | mindif
# Processing Record 38 of Set 11 | boende
# Processing Record 39 of Set 11 | sheltozero
# Processing Record 40 of Set 11 | salinopolis
# Processing Record 41 of Set 11 | hit
# Processing Record 42 of Set 11 | koutsouras
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | toora-khem
# Processing Record 45 of Set 11 | geraldton
# Processing Record 46 of Set 11 | ukiah
# Processing Record 47 of Set 11 | anton lizardo
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | aras
# Processing Record 50 of Set 11 | galle
# Processing Record 1 of Set 12 | olafsvik
# Processing Record 2 of Set 12 | tigil
# Processing Record 3 of Set 12 | comodoro rivadavia
# Processing Record 4 of Set 12 | nishihara
# Processing Record 5 of Set 12 | samarinda
# Processing Record 6 of Set 12 | vao
# Processing Record 7 of Set 12 | daru
# Processing Record 8 of Set 12 | ippy
# Processing Record 9 of Set 12 | nagorsk
# Processing Record 10 of Set 12 | birao
# Processing Record 11 of Set 12 | kavaratti
# Processing Record 12 of Set 12 | el estor
# Processing Record 13 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 12 | mitchell
# Processing Record 15 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 12 | seoul
# Processing Record 17 of Set 12 | challans
# Processing Record 18 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 12 | kijang
# Processing Record 20 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 12 | nyurba
# Processing Record 22 of Set 12 | doctor arroyo
# Processing Record 23 of Set 12 | lewistown
# Processing Record 24 of Set 12 | husavik
# Processing Record 25 of Set 12 | usinsk
# Processing Record 26 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 27 of Set 12 | ushtobe
# Processing Record 28 of Set 12 | shunyi
# Processing Record 29 of Set 12 | yichun
# Processing Record 30 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 31 of Set 12 | sagua la grande
# Processing Record 32 of Set 12 | athabasca
# Processing Record 33 of Set 12 | kudahuvadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# challenge objective 
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Vardo      NO  70.3705   31.1107     46.85        71
# 1        Port-Gentil      GA  -0.7193    8.7815     76.51        86
# 2        Clyde River      CA  70.4692  -68.5914     39.33        93
# 3              Muros      ES  42.7762   -9.0603     66.24        73
# 4             Bethel      US  41.3712  -73.4140     78.08        72
# ..               ...     ...      ...       ...       ...       ...
# 527           Shunyi      CN  40.1250  116.6453     73.35        78
# 528           Yichun      CN  47.7000  128.9000     66.65        67
# 529  Sagua La Grande      CU  22.8067  -80.0756     86.99        74
# 530        Athabasca      CA  54.7169 -113.2854     69.62        40
# 531     Kudahuvadhoo      MV   2.6708   72.8944     81.45        76
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0           100        9.40     overcast clouds           0.00              0
# 1           100       14.92          light rain           0.59              0
# 2           100        8.25     overcast clouds           0.00              0
# 3             6       15.46           clear sky           0.00              0
# 4             1        4.61           clear sky           0.00              0
# ..          ...         ...                 ...            ...            ...
# 527           0        8.95          light rain           0.13              0
# 528           3        1.92           clear sky           0.00              0
# 529          84       11.70       broken clouds           0.00              0
# 530          88       19.93     overcast clouds           0.00              0
# 531          97        8.32     overcast clouds           0.00              0
#
# [532 rows x 11 columns]

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 1       Port-Gentil      GA  -0.7193    8.7815     76.51        86
# 8        Nikolskoye      RU  59.7035   30.7861     59.02        86
# 37          Rikitea      PF -23.1203 -134.9692     74.57        80
# 47            Bluff      NZ -46.6000  168.3333     43.81        82
# 59         Souillac      MU -20.5167   57.5167     68.38        77
# 67  Arraial Do Cabo      BR -22.9661  -42.0278     69.94        86
# 77         Valparai      IN  10.3667   76.9667     62.37        89
# 80  Bambous Virieux      MU -20.3428   57.7575     68.25        77
# 87            Ancud      CL -41.8697  -73.8203     49.53        86
# 92       Butaritari      KI   3.0707  172.7902     83.12        75
#
#     Cloudiness  Wind Speed   Current Description  Rain (inches)  Snow (inches)
# 1          100       14.92            light rain           0.59              0
# 8           88        5.44            light rain           0.24              0
# 37           3       13.42            light rain           0.18              0
# 47          89       11.52            light rain           0.49              0
# 59          40       11.50            light rain           0.12              0
# 67          54       19.69  heavy intensity rain          11.53              0
# 77          99        3.13            light rain           0.87              0
# 80          40       11.50            light rain           0.29              0
# 87          83       23.04            light rain           0.58              0
# 92          28       12.41         moderate rain           1.01              0

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(10)
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
