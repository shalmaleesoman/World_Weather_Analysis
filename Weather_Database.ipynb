# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config3 import weather_api_key
from config_gmaps import g_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-bbb3a4e58e05> in <module>
#       7
#       8 from config3 import weather_api_key
# ----> 9 from config_gmaps import g_key
#
# ModuleNotFoundError: No module named 'config_gmaps'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 614

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "07b8063038a00b4adeb480983f0927b5"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | nuevo progreso
# Processing Record 5 of Set 1 | santa fe
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | caohai
# Processing Record 10 of Set 1 | talnakh
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | wajima
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | mehamn
# Processing Record 18 of Set 1 | ulladulla
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | hengshui
# Processing Record 24 of Set 1 | sorland
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | galchino
# City not found. Skipping...
# Processing Record 27 of Set 1 | olinda
# Processing Record 28 of Set 1 | labuhan
# Processing Record 29 of Set 1 | acapulco
# Processing Record 30 of Set 1 | akdepe
# Processing Record 31 of Set 1 | necochea
# Processing Record 32 of Set 1 | innisfail
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | talas
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | bilibino
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | tateyama
# Processing Record 40 of Set 1 | senno
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | syasstroy
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | korla
# Processing Record 45 of Set 1 | uporovo
# Processing Record 46 of Set 1 | riohacha
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | alice springs
# Processing Record 50 of Set 1 | igarape
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | port-gentil
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | perama
# Processing Record 5 of Set 2 | beloha
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | hofn
# Processing Record 9 of Set 2 | sambrial
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | holguin
# Processing Record 13 of Set 2 | mount gambier
# Processing Record 14 of Set 2 | fuyang
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | mahajanga
# Processing Record 18 of Set 2 | abu dhabi
# Processing Record 19 of Set 2 | zhangjiakou
# Processing Record 20 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 21 of Set 2 | jiazi
# Processing Record 22 of Set 2 | erzin
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | quelimane
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | umm kaddadah
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | catamarca
# Processing Record 30 of Set 2 | antofagasta
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | padang
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 2 | ossora
# Processing Record 37 of Set 2 | chimoio
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | odweyne
# Processing Record 42 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | jingdezhen
# Processing Record 45 of Set 2 | touros
# Processing Record 46 of Set 2 | whitehorse
# Processing Record 47 of Set 2 | basco
# Processing Record 48 of Set 2 | kabo
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | ocampo
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | watsa
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | camacha
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | husavik
# Processing Record 8 of Set 3 | abha
# Processing Record 9 of Set 3 | zhezkazgan
# Processing Record 10 of Set 3 | pochutla
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | grindavik
# Processing Record 13 of Set 3 | batabano
# Processing Record 14 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | makhinjauri
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | guatire
# Processing Record 20 of Set 3 | zhangye
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | muzhi
# Processing Record 23 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | rawson
# Processing Record 28 of Set 3 | windsor locks
# Processing Record 29 of Set 3 | catuday
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | bara
# Processing Record 32 of Set 3 | leshukonskoye
# Processing Record 33 of Set 3 | maarianhamina
# Processing Record 34 of Set 3 | viedma
# Processing Record 35 of Set 3 | college
# Processing Record 36 of Set 3 | velizh
# Processing Record 37 of Set 3 | kishtwar
# Processing Record 38 of Set 3 | vila do maio
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | caravelas
# Processing Record 41 of Set 3 | sur
# Processing Record 42 of Set 3 | kasongo-lunda
# Processing Record 43 of Set 3 | khandyga
# Processing Record 44 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 3 | waingapu
# Processing Record 46 of Set 3 | strezhevoy
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | lasa
# Processing Record 49 of Set 3 | waipawa
# Processing Record 50 of Set 3 | port blair
# Processing Record 1 of Set 4 | muros
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | cape town
# Processing Record 6 of Set 4 | tecpan
# Processing Record 7 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 4 | faro
# Processing Record 9 of Set 4 | havelock
# Processing Record 10 of Set 4 | meulaboh
# Processing Record 11 of Set 4 | muyezerskiy
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | the pas
# Processing Record 14 of Set 4 | lindsay
# Processing Record 15 of Set 4 | lipin bor
# Processing Record 16 of Set 4 | vila
# Processing Record 17 of Set 4 | burlington
# Processing Record 18 of Set 4 | ambon
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | tasiilaq
# Processing Record 21 of Set 4 | omboue
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | hobart
# Processing Record 24 of Set 4 | yar-sale
# Processing Record 25 of Set 4 | ornskoldsvik
# Processing Record 26 of Set 4 | jati
# Processing Record 27 of Set 4 | maple creek
# Processing Record 28 of Set 4 | ibicui
# Processing Record 29 of Set 4 | iisalmi
# Processing Record 30 of Set 4 | kirakira
# Processing Record 31 of Set 4 | airai
# Processing Record 32 of Set 4 | namatanai
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | pangnirtung
# Processing Record 35 of Set 4 | severo-kurilsk
# Processing Record 36 of Set 4 | bayangol
# Processing Record 37 of Set 4 | evensk
# Processing Record 38 of Set 4 | nishihara
# Processing Record 39 of Set 4 | york
# Processing Record 40 of Set 4 | roma
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | san carlos de bariloche
# Processing Record 43 of Set 4 | norman wells
# Processing Record 44 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 4 | rudnogorsk
# Processing Record 46 of Set 4 | westport
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | camana
# Processing Record 49 of Set 4 | hithadhoo
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | alyangula
# Processing Record 2 of Set 5 | pokrovsk
# Processing Record 3 of Set 5 | beaufort
# Processing Record 4 of Set 5 | kuching
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | stornoway
# Processing Record 9 of Set 5 | constantine
# Processing Record 10 of Set 5 | kitimat
# Processing Record 11 of Set 5 | east london
# Processing Record 12 of Set 5 | fort nelson
# Processing Record 13 of Set 5 | vredendal
# Processing Record 14 of Set 5 | palmer
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | cururupu
# Processing Record 17 of Set 5 | mahon
# Processing Record 18 of Set 5 | bud
# Processing Record 19 of Set 5 | pemba
# Processing Record 20 of Set 5 | hay river
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | tabou
# Processing Record 23 of Set 5 | angoche
# Processing Record 24 of Set 5 | custodia
# Processing Record 25 of Set 5 | waddan
# Processing Record 26 of Set 5 | ugoofaaru
# Processing Record 27 of Set 5 | samarai
# Processing Record 28 of Set 5 | xiaoshi
# Processing Record 29 of Set 5 | askarovo
# Processing Record 30 of Set 5 | cockburn town
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | aleksandrov gay
# Processing Record 33 of Set 5 | kaitangata
# Processing Record 34 of Set 5 | opuwo
# Processing Record 35 of Set 5 | prainha
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | motygino
# Processing Record 38 of Set 5 | ocos
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | yuci
# Processing Record 41 of Set 5 | fallon
# Processing Record 42 of Set 5 | ternate
# Processing Record 43 of Set 5 | ketchikan
# Processing Record 44 of Set 5 | santiago del estero
# Processing Record 45 of Set 5 | bull savanna
# Processing Record 46 of Set 5 | biak
# Processing Record 47 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 5 | georgetown
# Processing Record 49 of Set 5 | tucumcari
# Processing Record 50 of Set 5 | tessalit
# Processing Record 1 of Set 6 | aberdeen
# Processing Record 2 of Set 6 | palauig
# Processing Record 3 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 6 | noumea
# Processing Record 5 of Set 6 | tsabong
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | burica
# City not found. Skipping...
# Processing Record 8 of Set 6 | miyako
# Processing Record 9 of Set 6 | sinnamary
# Processing Record 10 of Set 6 | pimentel
# Processing Record 11 of Set 6 | mayo
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | olafsvik
# Processing Record 14 of Set 6 | marawi
# Processing Record 15 of Set 6 | dzhebariki-khaya
# Processing Record 16 of Set 6 | lithgow
# Processing Record 17 of Set 6 | medicine hat
# Processing Record 18 of Set 6 | iqaluit
# Processing Record 19 of Set 6 | sawakin
# Processing Record 20 of Set 6 | conde
# Processing Record 21 of Set 6 | ochando
# Processing Record 22 of Set 6 | new norfolk
# Processing Record 23 of Set 6 | te anau
# Processing Record 24 of Set 6 | altamura
# Processing Record 25 of Set 6 | benguela
# Processing Record 26 of Set 6 | abnub
# Processing Record 27 of Set 6 | chauk
# Processing Record 28 of Set 6 | qianjiang
# Processing Record 29 of Set 6 | bafoulabe
# Processing Record 30 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 6 | tromso
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | karlskrona
# Processing Record 34 of Set 6 | port macquarie
# Processing Record 35 of Set 6 | jega
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | taonan
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | maltahohe
# Processing Record 41 of Set 6 | makat
# Processing Record 42 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 43 of Set 6 | miracema do tocantins
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | akersberga
# Processing Record 46 of Set 6 | haines junction
# Processing Record 47 of Set 6 | miandrivazo
# Processing Record 48 of Set 6 | palmerston north
# Processing Record 49 of Set 6 | santa cruz
# Processing Record 50 of Set 6 | orangeburg
# Processing Record 1 of Set 7 | cidreira
# Processing Record 2 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 7 | hohhot
# Processing Record 4 of Set 7 | akhnur
# Processing Record 5 of Set 7 | avera
# Processing Record 6 of Set 7 | gogrial
# Processing Record 7 of Set 7 | nago
# Processing Record 8 of Set 7 | sola
# Processing Record 9 of Set 7 | hambantota
# Processing Record 10 of Set 7 | tucurui
# Processing Record 11 of Set 7 | pingzhuang
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | tura
# Processing Record 14 of Set 7 | palaikastron
# Processing Record 15 of Set 7 | jumla
# Processing Record 16 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 7 | coihaique
# Processing Record 18 of Set 7 | bonfim
# Processing Record 19 of Set 7 | los zacatones
# Processing Record 20 of Set 7 | brae
# Processing Record 21 of Set 7 | soyo
# Processing Record 22 of Set 7 | puerto madryn
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | san juan
# Processing Record 25 of Set 7 | campo grande
# Processing Record 26 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 27 of Set 7 | inirida
# Processing Record 28 of Set 7 | saint anthony
# Processing Record 29 of Set 7 | jardim
# Processing Record 30 of Set 7 | lerwick
# Processing Record 31 of Set 7 | bengkulu
# Processing Record 32 of Set 7 | jalna
# Processing Record 33 of Set 7 | dukat
# Processing Record 34 of Set 7 | taoudenni
# Processing Record 35 of Set 7 | nadym
# Processing Record 36 of Set 7 | magole
# Processing Record 37 of Set 7 | bentiu
# Processing Record 38 of Set 7 | caluquembe
# Processing Record 39 of Set 7 | ahrensburg
# Processing Record 40 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 41 of Set 7 | semnan
# Processing Record 42 of Set 7 | okhotsk
# Processing Record 43 of Set 7 | parintins
# Processing Record 44 of Set 7 | longyearbyen
# Processing Record 45 of Set 7 | scarborough
# Processing Record 46 of Set 7 | chuy
# Processing Record 47 of Set 7 | buala
# Processing Record 48 of Set 7 | beaverlodge
# Processing Record 49 of Set 7 | harper
# Processing Record 50 of Set 7 | katsuura
# Processing Record 1 of Set 8 | beringovskiy
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | turukhansk
# Processing Record 5 of Set 8 | da nang
# Processing Record 6 of Set 8 | kimbe
# Processing Record 7 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 8 | moose factory
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 11 of Set 8 | novikovo
# Processing Record 12 of Set 8 | bathsheba
# Processing Record 13 of Set 8 | atambua
# Processing Record 14 of Set 8 | rock sound
# Processing Record 15 of Set 8 | qaqortoq
# Processing Record 16 of Set 8 | las choapas
# Processing Record 17 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 8 | west bay
# Processing Record 19 of Set 8 | martinsville
# Processing Record 20 of Set 8 | faya
# Processing Record 21 of Set 8 | kilindoni
# Processing Record 22 of Set 8 | erenhot
# Processing Record 23 of Set 8 | crib point
# Processing Record 24 of Set 8 | aylmer
# Processing Record 25 of Set 8 | aksha
# Processing Record 26 of Set 8 | labis
# Processing Record 27 of Set 8 | solnechnyy
# Processing Record 28 of Set 8 | san vicente
# Processing Record 29 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 8 | santiago
# Processing Record 31 of Set 8 | valdivia
# Processing Record 32 of Set 8 | markova
# Processing Record 33 of Set 8 | kasongo
# Processing Record 34 of Set 8 | bonthe
# Processing Record 35 of Set 8 | shahr-e babak
# Processing Record 36 of Set 8 | koumac
# Processing Record 37 of Set 8 | portland
# Processing Record 38 of Set 8 | ixtapa
# Processing Record 39 of Set 8 | najran
# Processing Record 40 of Set 8 | oranjemund
# Processing Record 41 of Set 8 | orlik
# Processing Record 42 of Set 8 | vestmanna
# Processing Record 43 of Set 8 | san jeronimo
# Processing Record 44 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 8 | la ronge
# Processing Record 46 of Set 8 | san jose
# Processing Record 47 of Set 8 | vaitape
# Processing Record 48 of Set 8 | tarauaca
# Processing Record 49 of Set 8 | gayny
# Processing Record 50 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 9 | anan
# Processing Record 2 of Set 9 | phalodi
# Processing Record 3 of Set 9 | bonavista
# Processing Record 4 of Set 9 | kathu
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | newport
# Processing Record 7 of Set 9 | lalmohan
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | iguape
# Processing Record 10 of Set 9 | chillicothe
# Processing Record 11 of Set 9 | jewar
# Processing Record 12 of Set 9 | kuryk
# Processing Record 13 of Set 9 | wanning
# Processing Record 14 of Set 9 | tibagi
# Processing Record 15 of Set 9 | kamaishi
# Processing Record 16 of Set 9 | oistins
# Processing Record 17 of Set 9 | vila franca do campo
# Processing Record 18 of Set 9 | coffs harbour
# Processing Record 19 of Set 9 | shankargarh
# Processing Record 20 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 9 | fez
# Processing Record 22 of Set 9 | tazovskiy
# Processing Record 23 of Set 9 | shevchenkove
# Processing Record 24 of Set 9 | northam
# Processing Record 25 of Set 9 | porto seguro
# Processing Record 26 of Set 9 | mackenzie
# Processing Record 27 of Set 9 | teguldet
# Processing Record 28 of Set 9 | florianopolis
# Processing Record 29 of Set 9 | knysna
# Processing Record 30 of Set 9 | novyy urengoy
# Processing Record 31 of Set 9 | vryburg
# Processing Record 32 of Set 9 | les escoumins
# Processing Record 33 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 9 | chokurdakh
# Processing Record 35 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 9 | eirunepe
# Processing Record 37 of Set 9 | hami
# Processing Record 38 of Set 9 | raton
# Processing Record 39 of Set 9 | buraydah
# Processing Record 40 of Set 9 | ahuimanu
# Processing Record 41 of Set 9 | keetmanshoop
# Processing Record 42 of Set 9 | zhanakorgan
# Processing Record 43 of Set 9 | nemuro
# Processing Record 44 of Set 9 | praxedis guerrero
# Processing Record 45 of Set 9 | palana
# Processing Record 46 of Set 9 | lavrentiya
# Processing Record 47 of Set 9 | touho
# Processing Record 48 of Set 9 | seoul
# Processing Record 49 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 9 | metro
# Processing Record 1 of Set 10 | zharkent
# Processing Record 2 of Set 10 | verkhoyansk
# Processing Record 3 of Set 10 | eureka
# Processing Record 4 of Set 10 | codrington
# Processing Record 5 of Set 10 | krasnogorsk
# Processing Record 6 of Set 10 | poshekhonye
# Processing Record 7 of Set 10 | anadyr
# Processing Record 8 of Set 10 | high level
# Processing Record 9 of Set 10 | sao joao da barra
# Processing Record 10 of Set 10 | zhigansk
# Processing Record 11 of Set 10 | tokuyama
# Processing Record 12 of Set 10 | melfort
# Processing Record 13 of Set 10 | paamiut
# Processing Record 14 of Set 10 | pisco
# Processing Record 15 of Set 10 | inhambane
# Processing Record 16 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 17 of Set 10 | san ramon
# Processing Record 18 of Set 10 | comodoro rivadavia
# Processing Record 19 of Set 10 | paris
# Processing Record 20 of Set 10 | duz
# City not found. Skipping...
# Processing Record 21 of Set 10 | pangoa
# Processing Record 22 of Set 10 | gunjur
# Processing Record 23 of Set 10 | aswan
# Processing Record 24 of Set 10 | alofi
# Processing Record 25 of Set 10 | galveston
# Processing Record 26 of Set 10 | hamilton
# Processing Record 27 of Set 10 | takoradi
# Processing Record 28 of Set 10 | shenjiamen
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | bubaque
# Processing Record 31 of Set 10 | port-cartier
# Processing Record 32 of Set 10 | lakes entrance
# Processing Record 33 of Set 10 | lensk
# Processing Record 34 of Set 10 | lucea
# Processing Record 35 of Set 10 | elko
# Processing Record 36 of Set 10 | at-bashi
# Processing Record 37 of Set 10 | baiquan
# Processing Record 38 of Set 10 | cabo san lucas
# Processing Record 39 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 10 | nouadhibou
# Processing Record 41 of Set 10 | ahipara
# Processing Record 42 of Set 10 | dukhovshchina
# Processing Record 43 of Set 10 | saint-joseph
# Processing Record 44 of Set 10 | pacific grove
# Processing Record 45 of Set 10 | maketu
# Processing Record 46 of Set 10 | ilulissat
# Processing Record 47 of Set 10 | vanimo
# Processing Record 48 of Set 10 | nizhniy odes
# Processing Record 49 of Set 10 | zastron
# Processing Record 50 of Set 10 | okha
# Processing Record 1 of Set 11 | malanje
# Processing Record 2 of Set 11 | dingle
# Processing Record 3 of Set 11 | nizhnyaya omka
# Processing Record 4 of Set 11 | ventspils
# Processing Record 5 of Set 11 | barra patuca
# Processing Record 6 of Set 11 | inzhavino
# Processing Record 7 of Set 11 | sept-iles
# Processing Record 8 of Set 11 | kirovsk
# Processing Record 9 of Set 11 | urumqi
# Processing Record 10 of Set 11 | mwingi
# Processing Record 11 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 11 | grand gaube
# Processing Record 13 of Set 11 | cortez
# Processing Record 14 of Set 11 | verkhnyaya toyma
# Processing Record 15 of Set 11 | bowling green
# Processing Record 16 of Set 11 | vilyuysk
# Processing Record 17 of Set 11 | rancho palos verdes
# Processing Record 18 of Set 11 | orem
# Processing Record 19 of Set 11 | adrar
# Processing Record 20 of Set 11 | moerai
# Processing Record 21 of Set 11 | verkh-usugli
# Processing Record 22 of Set 11 | inverness
# Processing Record 23 of Set 11 | ludvika
# Processing Record 24 of Set 11 | broome
# Processing Record 25 of Set 11 | lagoa
# Processing Record 26 of Set 11 | ruteng
# Processing Record 27 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 11 | manado
# Processing Record 29 of Set 11 | guarapari
# Processing Record 30 of Set 11 | nakhon sawan
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | ouesso
# Processing Record 33 of Set 11 | blenheim
# Processing Record 34 of Set 11 | yarmouth
# Processing Record 35 of Set 11 | mahina
# Processing Record 36 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 38 of Set 11 | misratah
# Processing Record 39 of Set 11 | kangaatsiaq
# Processing Record 40 of Set 11 | talaya
# Processing Record 41 of Set 11 | henties bay
# Processing Record 42 of Set 11 | doha
# Processing Record 43 of Set 11 | telixtac
# Processing Record 44 of Set 11 | shimoda
# Processing Record 45 of Set 11 | verkhnevilyuysk
# Processing Record 46 of Set 11 | vostok
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | khasan
# Processing Record 49 of Set 11 | yamada
# Processing Record 50 of Set 11 | barao de melgaco
# Processing Record 1 of Set 12 | bitung
# Processing Record 2 of Set 12 | constitucion
# Processing Record 3 of Set 12 | dongsheng
# Processing Record 4 of Set 12 | edd
# Processing Record 5 of Set 12 | pitelino
# Processing Record 6 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 12 | nacala
# Processing Record 8 of Set 12 | killybegs
# Processing Record 9 of Set 12 | mounana
# Processing Record 10 of Set 12 | lodja
# Processing Record 11 of Set 12 | quthing
# Processing Record 12 of Set 12 | kangaba
# Processing Record 13 of Set 12 | ancud
# Processing Record 14 of Set 12 | kemijarvi
# Processing Record 15 of Set 12 | vinukonda
# Processing Record 16 of Set 12 | porto franco
# Processing Record 17 of Set 12 | tocopilla
# Processing Record 18 of Set 12 | pau brasil
# Processing Record 19 of Set 12 | bristol
# Processing Record 20 of Set 12 | cartagena
# Processing Record 21 of Set 12 | kerema
# Processing Record 22 of Set 12 | san rafael
# Processing Record 23 of Set 12 | genhe
# Processing Record 24 of Set 12 | gerede
# Processing Record 25 of Set 12 | haapiti
# Processing Record 26 of Set 12 | hobyo
# Processing Record 27 of Set 12 | daru
# Processing Record 28 of Set 12 | yokadouma
# Processing Record 29 of Set 12 | banda aceh
# Processing Record 30 of Set 12 | vytegra
# Processing Record 31 of Set 12 | myitkyina
# Processing Record 32 of Set 12 | aksu
# Processing Record 33 of Set 12 | mogadishu
# Processing Record 34 of Set 12 | mirnyy
# Processing Record 35 of Set 12 | ust-kuyga
# Processing Record 36 of Set 12 | malatya
# Processing Record 37 of Set 12 | ulundurpettai
# City not found. Skipping...
# Processing Record 38 of Set 12 | puerto penasco
# Processing Record 39 of Set 12 | port hedland
# Processing Record 40 of Set 12 | clyde
# Processing Record 41 of Set 12 | oktyabrskiy
# Processing Record 42 of Set 12 | rio grande
# Processing Record 43 of Set 12 | bagdarin
# Processing Record 44 of Set 12 | severo-yeniseyskiy
# Processing Record 45 of Set 12 | kidal
# Processing Record 46 of Set 12 | tangshan
# Processing Record 47 of Set 12 | haicheng
# Processing Record 48 of Set 12 | rutland
# Processing Record 49 of Set 12 | nuuk
# Processing Record 50 of Set 12 | tarabha
# Processing Record 1 of Set 13 | lev tolstoy
# Processing Record 2 of Set 13 | oranjestad
# Processing Record 3 of Set 13 | saa
# Processing Record 4 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 13 | grande prairie
# Processing Record 7 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 13 | bourges
# Processing Record 9 of Set 13 | xinzhou
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | nagato
# Processing Record 12 of Set 13 | wolfsburg
# Processing Record 13 of Set 13 | ust-nera
# Processing Record 14 of Set 13 | kupang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | andenes
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | pangnirtung
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | lircay
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | ulladulla
# Processing Record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 1 | sorland
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | nome
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | santa leopoldina
# Processing Record 22 of Set 1 | gazli
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | fort saint james
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | beyneu
# Processing Record 27 of Set 1 | churapcha
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | richards bay
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | abu samrah
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | walvis bay
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | saint-pierre
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | prestea
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | dawlatabad
# Processing Record 46 of Set 1 | baghmara
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | grand gaube
# Processing Record 49 of Set 1 | noumea
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | nichinan
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | vreed en hoop
# City not found. Skipping...
# Processing Record 7 of Set 2 | fairbanks
# Processing Record 8 of Set 2 | kishorganj
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | husavik
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | lorengau
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | pahrump
# Processing Record 16 of Set 2 | mount gambier
# Processing Record 17 of Set 2 | caravelas
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | katsuura
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | morros
# Processing Record 25 of Set 2 | kalemie
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 2 | jiuquan
# Processing Record 30 of Set 2 | felanitx
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 2 | steinbach
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | pasaje
# Processing Record 36 of Set 2 | havoysund
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | los chiles
# Processing Record 39 of Set 2 | molteno
# Processing Record 40 of Set 2 | la palma
# Processing Record 41 of Set 2 | rosita
# Processing Record 42 of Set 2 | tura
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | novoagansk
# Processing Record 45 of Set 2 | faya
# Processing Record 46 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | shenjiamen
# Processing Record 49 of Set 2 | jumla
# Processing Record 50 of Set 2 | la ronge
# Processing Record 1 of Set 3 | san rafael
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | seoul
# Processing Record 5 of Set 3 | baruun-urt
# Processing Record 6 of Set 3 | guerrero
# Processing Record 7 of Set 3 | mujiayingzi
# Processing Record 8 of Set 3 | aloleng
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | ranong
# Processing Record 11 of Set 3 | scarborough
# Processing Record 12 of Set 3 | papara
# Processing Record 13 of Set 3 | bar harbor
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | tariba
# Processing Record 16 of Set 3 | ambilobe
# Processing Record 17 of Set 3 | vanavara
# Processing Record 18 of Set 3 | san policarpo
# Processing Record 19 of Set 3 | golden
# Processing Record 20 of Set 3 | kaitangata
# Processing Record 21 of Set 3 | saint-joseph
# Processing Record 22 of Set 3 | sulangan
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | matamoros
# Processing Record 25 of Set 3 | veinticinco de mayo
# Processing Record 26 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | rapid valley
# Processing Record 29 of Set 3 | juneau
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | dwarka
# Processing Record 32 of Set 3 | kahului
# Processing Record 33 of Set 3 | kloulklubed
# Processing Record 34 of Set 3 | buchanan
# Processing Record 35 of Set 3 | beloha
# Processing Record 36 of Set 3 | half moon bay
# Processing Record 37 of Set 3 | zelenoborsk
# Processing Record 38 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | dzhebariki-khaya
# Processing Record 42 of Set 3 | plettenberg bay
# Processing Record 43 of Set 3 | sao felix do xingu
# Processing Record 44 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | stromness
# Processing Record 47 of Set 3 | ketchikan
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | at-bashi
# Processing Record 1 of Set 4 | isangel
# Processing Record 2 of Set 4 | zephyrhills
# Processing Record 3 of Set 4 | margate
# Processing Record 4 of Set 4 | alta floresta
# Processing Record 5 of Set 4 | samfya
# Processing Record 6 of Set 4 | benevides
# Processing Record 7 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 4 | borogontsy
# Processing Record 9 of Set 4 | coahuayana
# Processing Record 10 of Set 4 | luanda
# Processing Record 11 of Set 4 | verkhniye tatyshly
# Processing Record 12 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 4 | saint-georges
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | aleksandrovsk-sakhalinskiy
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | srednekolymsk
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | cayenne
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | voloshka
# Processing Record 24 of Set 4 | jiangkou
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | luganville
# Processing Record 27 of Set 4 | abeche
# Processing Record 28 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 4 | staryy nadym
# Processing Record 30 of Set 4 | berck
# Processing Record 31 of Set 4 | belyy yar
# Processing Record 32 of Set 4 | kindu
# Processing Record 33 of Set 4 | san pedro de ycuamandiyu
# Processing Record 34 of Set 4 | vila
# Processing Record 35 of Set 4 | kruisfontein
# Processing Record 36 of Set 4 | honiara
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | haverfordwest
# Processing Record 40 of Set 4 | oriximina
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | chapadinha
# Processing Record 43 of Set 4 | baykit
# Processing Record 44 of Set 4 | bosaso
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | tiznit
# Processing Record 47 of Set 4 | yerbogachen
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | itupeva
# Processing Record 50 of Set 4 | yulara
# Processing Record 1 of Set 5 | guozhen
# Processing Record 2 of Set 5 | inhambane
# Processing Record 3 of Set 5 | santa maria
# Processing Record 4 of Set 5 | udachnyy
# Processing Record 5 of Set 5 | seryshevo
# Processing Record 6 of Set 5 | sigli
# Processing Record 7 of Set 5 | antofagasta
# Processing Record 8 of Set 5 | nouadhibou
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | makakilo city
# Processing Record 11 of Set 5 | haines junction
# Processing Record 12 of Set 5 | aswan
# Processing Record 13 of Set 5 | am timan
# Processing Record 14 of Set 5 | kyra
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 5 | lalmohan
# Processing Record 17 of Set 5 | saquarema
# Processing Record 18 of Set 5 | tautira
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | poum
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | parainen
# Processing Record 23 of Set 5 | santa marta
# Processing Record 24 of Set 5 | atambua
# Processing Record 25 of Set 5 | new norfolk
# Processing Record 26 of Set 5 | haian
# Processing Record 27 of Set 5 | port hedland
# Processing Record 28 of Set 5 | gat
# Processing Record 29 of Set 5 | filingue
# Processing Record 30 of Set 5 | yuanping
# Processing Record 31 of Set 5 | norman wells
# Processing Record 32 of Set 5 | alice springs
# Processing Record 33 of Set 5 | mayumba
# Processing Record 34 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | assens
# Processing Record 39 of Set 5 | yar-sale
# Processing Record 40 of Set 5 | beringovskiy
# Processing Record 41 of Set 5 | dicabisagan
# Processing Record 42 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 43 of Set 5 | siocon
# Processing Record 44 of Set 5 | oistins
# Processing Record 45 of Set 5 | iralaya
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 50 of Set 5 | cairns
# Processing Record 1 of Set 6 | kampot
# Processing Record 2 of Set 6 | torbay
# Processing Record 3 of Set 6 | jingdezhen
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | ternate
# Processing Record 6 of Set 6 | aguimes
# Processing Record 7 of Set 6 | shimoda
# Processing Record 8 of Set 6 | praya
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | maldonado
# Processing Record 11 of Set 6 | chernyshevskiy
# Processing Record 12 of Set 6 | dhidhdhoo
# Processing Record 13 of Set 6 | linhares
# Processing Record 14 of Set 6 | acapulco
# Processing Record 15 of Set 6 | san patricio
# Processing Record 16 of Set 6 | dongsheng
# Processing Record 17 of Set 6 | thinadhoo
# Processing Record 18 of Set 6 | swakopmund
# Processing Record 19 of Set 6 | pangody
# Processing Record 20 of Set 6 | auki
# Processing Record 21 of Set 6 | sungairaya
# Processing Record 22 of Set 6 | zyryanka
# Processing Record 23 of Set 6 | esperance
# Processing Record 24 of Set 6 | dunda
# Processing Record 25 of Set 6 | soyo
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | payakumbuh
# Processing Record 28 of Set 6 | sao pedro do sul
# Processing Record 29 of Set 6 | morro bay
# Processing Record 30 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 6 | waddan
# Processing Record 32 of Set 6 | chester
# Processing Record 33 of Set 6 | nueva italia de ruiz
# Processing Record 34 of Set 6 | namibe
# Processing Record 35 of Set 6 | strathpeffer
# Processing Record 36 of Set 6 | hokitika
# Processing Record 37 of Set 6 | jieznas
# Processing Record 38 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 6 | halifax
# Processing Record 40 of Set 6 | thiruvananthapuram
# Processing Record 41 of Set 6 | dubrovnik
# Processing Record 42 of Set 6 | buala
# Processing Record 43 of Set 6 | altay
# Processing Record 44 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 6 | eyl
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | urumqi
# Processing Record 48 of Set 6 | hualmay
# Processing Record 49 of Set 6 | krasnoselkup
# Processing Record 50 of Set 6 | aksu
# Processing Record 1 of Set 7 | agadir
# Processing Record 2 of Set 7 | yambio
# Processing Record 3 of Set 7 | iqaluit
# Processing Record 4 of Set 7 | vostok
# Processing Record 5 of Set 7 | aitape
# Processing Record 6 of Set 7 | pendleton
# Processing Record 7 of Set 7 | andrews
# Processing Record 8 of Set 7 | kingman
# Processing Record 9 of Set 7 | mareeba
# Processing Record 10 of Set 7 | dera din panah
# City not found. Skipping...
# Processing Record 11 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 7 | terrace
# Processing Record 13 of Set 7 | the valley
# Processing Record 14 of Set 7 | roald
# Processing Record 15 of Set 7 | salalah
# Processing Record 16 of Set 7 | ulaangom
# Processing Record 17 of Set 7 | ambulu
# Processing Record 18 of Set 7 | tuktoyaktuk
# Processing Record 19 of Set 7 | apastovo
# Processing Record 20 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 7 | rio grande
# Processing Record 22 of Set 7 | spornoye
# Processing Record 23 of Set 7 | kensington
# Processing Record 24 of Set 7 | solvychegodsk
# Processing Record 25 of Set 7 | aykhal
# Processing Record 26 of Set 7 | hambantota
# Processing Record 27 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | maniitsoq
# Processing Record 30 of Set 7 | marshall
# Processing Record 31 of Set 7 | parole
# Processing Record 32 of Set 7 | itarema
# Processing Record 33 of Set 7 | yumen
# Processing Record 34 of Set 7 | sorong
# Processing Record 35 of Set 7 | san quintin
# Processing Record 36 of Set 7 | kotelnikovo
# Processing Record 37 of Set 7 | talaya
# Processing Record 38 of Set 7 | cidreira
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | saint anthony
# Processing Record 41 of Set 7 | elliot lake
# Processing Record 42 of Set 7 | urulga
# City not found. Skipping...
# Processing Record 43 of Set 7 | svetlogorsk
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 7 | krasnovishersk
# Processing Record 48 of Set 7 | brae
# Processing Record 49 of Set 7 | ixtapa
# Processing Record 50 of Set 7 | davila
# Processing Record 1 of Set 8 | warri
# Processing Record 2 of Set 8 | russell
# Processing Record 3 of Set 8 | invercargill
# Processing Record 4 of Set 8 | coihaique
# Processing Record 5 of Set 8 | porto torres
# Processing Record 6 of Set 8 | riyadh
# Processing Record 7 of Set 8 | ust-omchug
# Processing Record 8 of Set 8 | ontario
# Processing Record 9 of Set 8 | nicoya
# Processing Record 10 of Set 8 | goderich
# Processing Record 11 of Set 8 | le mans
# Processing Record 12 of Set 8 | mbacke
# City not found. Skipping...
# Processing Record 13 of Set 8 | karratha
# Processing Record 14 of Set 8 | sur
# Processing Record 15 of Set 8 | urucara
# Processing Record 16 of Set 8 | rurrenabaque
# Processing Record 17 of Set 8 | quatre cocos
# Processing Record 18 of Set 8 | dogondoutchi
# Processing Record 19 of Set 8 | rogers
# Processing Record 20 of Set 8 | yasnyy
# Processing Record 21 of Set 8 | piripiri
# Processing Record 22 of Set 8 | chokurdakh
# Processing Record 23 of Set 8 | melo
# Processing Record 24 of Set 8 | dunedin
# Processing Record 25 of Set 8 | hay river
# Processing Record 26 of Set 8 | avera
# Processing Record 27 of Set 8 | quelimane
# Processing Record 28 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 8 | fort nelson
# Processing Record 30 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 8 | port blair
# Processing Record 32 of Set 8 | dingle
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | high rock
# Processing Record 35 of Set 8 | sauteurs
# Processing Record 36 of Set 8 | prince rupert
# Processing Record 37 of Set 8 | maragogi
# Processing Record 38 of Set 8 | pizarro
# Processing Record 39 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 8 | montes altos
# Processing Record 41 of Set 8 | porto velho
# Processing Record 42 of Set 8 | san jeronimo
# Processing Record 43 of Set 8 | coquimbo
# Processing Record 44 of Set 8 | lima
# Processing Record 45 of Set 8 | shanghai
# Processing Record 46 of Set 8 | cabo san lucas
# Processing Record 47 of Set 8 | catuday
# Processing Record 48 of Set 8 | arlit
# Processing Record 49 of Set 8 | tazovskiy
# Processing Record 50 of Set 8 | sinnamary
# Processing Record 1 of Set 9 | miandrivazo
# Processing Record 2 of Set 9 | vanimo
# Processing Record 3 of Set 9 | tateyama
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | vestmanna
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | kavieng
# Processing Record 8 of Set 9 | homer
# Processing Record 9 of Set 9 | seybaplaya
# Processing Record 10 of Set 9 | anadyr
# Processing Record 11 of Set 9 | bac lieu
# Processing Record 12 of Set 9 | sao jose da coroa grande
# Processing Record 13 of Set 9 | guangyuan
# Processing Record 14 of Set 9 | bay city
# Processing Record 15 of Set 9 | bridlington
# Processing Record 16 of Set 9 | damietta
# Processing Record 17 of Set 9 | jelling
# Processing Record 18 of Set 9 | niquelandia
# Processing Record 19 of Set 9 | ulaanbaatar
# Processing Record 20 of Set 9 | polyarnyy
# Processing Record 21 of Set 9 | katherine
# Processing Record 22 of Set 9 | kaya
# Processing Record 23 of Set 9 | makat
# Processing Record 24 of Set 9 | huangpi
# Processing Record 25 of Set 9 | lola
# Processing Record 26 of Set 9 | raudeberg
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 9 | ishigaki
# Processing Record 30 of Set 9 | sept-iles
# Processing Record 31 of Set 9 | swift current
# Processing Record 32 of Set 9 | conselheiro lafaiete
# Processing Record 33 of Set 9 | atar
# Processing Record 34 of Set 9 | coyotepec
# Processing Record 35 of Set 9 | ostrovnoy
# Processing Record 36 of Set 9 | killybegs
# Processing Record 37 of Set 9 | buraydah
# Processing Record 38 of Set 9 | katobu
# Processing Record 39 of Set 9 | maralal
# Processing Record 40 of Set 9 | talnakh
# Processing Record 41 of Set 9 | port augusta
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | evensk
# Processing Record 44 of Set 9 | adrar
# Processing Record 45 of Set 9 | kilimatinde
# Processing Record 46 of Set 9 | levelland
# Processing Record 47 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 9 | pacific grove
# Processing Record 49 of Set 9 | port hardy
# Processing Record 50 of Set 9 | roebourne
# Processing Record 1 of Set 10 | chumikan
# Processing Record 2 of Set 10 | kiyevskoye
# Processing Record 3 of Set 10 | abu dhabi
# Processing Record 4 of Set 10 | northport
# Processing Record 5 of Set 10 | kirakira
# Processing Record 6 of Set 10 | turukhansk
# Processing Record 7 of Set 10 | sosnovo-ozerskoye
# Processing Record 8 of Set 10 | henties bay
# Processing Record 9 of Set 10 | kostomuksha
# Processing Record 10 of Set 10 | kovvur
# Processing Record 11 of Set 10 | badiraguato
# Processing Record 12 of Set 10 | capelinha
# Processing Record 13 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 10 | marsabit
# Processing Record 16 of Set 10 | mackay
# Processing Record 17 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 10 | phalaborwa
# Processing Record 19 of Set 10 | daur
# Processing Record 20 of Set 10 | zhenlai
# Processing Record 21 of Set 10 | great yarmouth
# Processing Record 22 of Set 10 | ropczyce
# Processing Record 23 of Set 10 | mahebourg
# Processing Record 24 of Set 10 | dalvik
# Processing Record 25 of Set 10 | koslan
# Processing Record 26 of Set 10 | dzilam gonzalez
# Processing Record 27 of Set 10 | vila franca do campo
# Processing Record 28 of Set 10 | raga
# Processing Record 29 of Set 10 | quang ngai
# Processing Record 30 of Set 10 | kameno
# Processing Record 31 of Set 10 | la joya
# Processing Record 32 of Set 10 | deyang
# Processing Record 33 of Set 10 | pochutla
# Processing Record 34 of Set 10 | qaqortoq
# Processing Record 35 of Set 10 | marechal deodoro
# Processing Record 36 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 10 | paamiut
# Processing Record 38 of Set 10 | general roca
# Processing Record 39 of Set 10 | tabou
# Processing Record 40 of Set 10 | salina cruz
# Processing Record 41 of Set 10 | vestmannaeyjar
# Processing Record 42 of Set 10 | sioux lookout
# Processing Record 43 of Set 10 | umm lajj
# Processing Record 44 of Set 10 | shenkursk
# Processing Record 45 of Set 10 | carsamba
# Processing Record 46 of Set 10 | pozo colorado
# Processing Record 47 of Set 10 | tamandare
# Processing Record 48 of Set 10 | kharagauli
# Processing Record 49 of Set 10 | kokkola
# Processing Record 50 of Set 10 | troitskoye
# Processing Record 1 of Set 11 | namatanai
# Processing Record 2 of Set 11 | kichera
# Processing Record 3 of Set 11 | iwanai
# Processing Record 4 of Set 11 | outram
# Processing Record 5 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 11 | shelburne
# Processing Record 7 of Set 11 | jiayuguan
# Processing Record 8 of Set 11 | sitka
# Processing Record 9 of Set 11 | pandan
# Processing Record 10 of Set 11 | north bend
# Processing Record 11 of Set 11 | were ilu
# Processing Record 12 of Set 11 | liling
# Processing Record 13 of Set 11 | praia
# Processing Record 14 of Set 11 | bonavista
# Processing Record 15 of Set 11 | saint combs
# City not found. Skipping...
# Processing Record 16 of Set 11 | port lincoln
# Processing Record 17 of Set 11 | aripuana
# Processing Record 18 of Set 11 | fukue
# Processing Record 19 of Set 11 | hun
# Processing Record 20 of Set 11 | agua prieta
# Processing Record 21 of Set 11 | meybod
# Processing Record 22 of Set 11 | los llanos de aridane
# Processing Record 23 of Set 11 | leningradskiy
# Processing Record 24 of Set 11 | mayor pablo lagerenza
# Processing Record 25 of Set 11 | bud
# Processing Record 26 of Set 11 | dubbo
# Processing Record 27 of Set 11 | acarau
# Processing Record 28 of Set 11 | sarnia
# Processing Record 29 of Set 11 | rognac
# Processing Record 30 of Set 11 | qianan
# Processing Record 31 of Set 11 | sinjar
# Processing Record 32 of Set 11 | samarai
# Processing Record 33 of Set 11 | la paz
# Processing Record 34 of Set 11 | gunjur
# Processing Record 35 of Set 11 | namie
# Processing Record 36 of Set 11 | dali
# Processing Record 37 of Set 11 | magan
# Processing Record 38 of Set 11 | tamsweg
# Processing Record 39 of Set 11 | san vicente
# Processing Record 40 of Set 11 | kamaishi
# Processing Record 41 of Set 11 | ilulissat
# Processing Record 42 of Set 11 | sambava
# Processing Record 43 of Set 11 | acajutla
# Processing Record 44 of Set 11 | petatlan
# Processing Record 45 of Set 11 | palmer
# Processing Record 46 of Set 11 | port-gentil
# Processing Record 47 of Set 11 | kasongo-lunda
# Processing Record 48 of Set 11 | college
# Processing Record 49 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 11 | denton
# Processing Record 1 of Set 12 | xinye
# Processing Record 2 of Set 12 | nisia floresta
# Processing Record 3 of Set 12 | stornoway
# Processing Record 4 of Set 12 | mugan
# Processing Record 5 of Set 12 | moron
# Processing Record 6 of Set 12 | mingoyo
# Processing Record 7 of Set 12 | ondangwa
# Processing Record 8 of Set 12 | lasa
# Processing Record 9 of Set 12 | hovd
# Processing Record 10 of Set 12 | kambove
# Processing Record 11 of Set 12 | muli
# Processing Record 12 of Set 12 | dongzhen
# Processing Record 13 of Set 12 | presidencia roque saenz pena
# Processing Record 14 of Set 12 | okha
# Processing Record 15 of Set 12 | harper
# Processing Record 16 of Set 12 | selfoss
# Processing Record 17 of Set 12 | kaeo
# Processing Record 18 of Set 12 | rodrigues alves
# Processing Record 19 of Set 12 | mehamn
# Processing Record 20 of Set 12 | alcains
# Processing Record 21 of Set 12 | axim
# Processing Record 22 of Set 12 | vigrestad
# Processing Record 23 of Set 12 | akyab
# Processing Record 24 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | stara vyzhivka
# Processing Record 27 of Set 12 | vilhena
# Processing Record 28 of Set 12 | varhaug
# Processing Record 29 of Set 12 | chara
# Processing Record 30 of Set 12 | tobe
# Processing Record 31 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 12 | tupik
# Processing Record 33 of Set 12 | kudahuvadhoo
# Processing Record 34 of Set 12 | mirpur sakro
# Processing Record 35 of Set 12 | daru
# Processing Record 36 of Set 12 | westport
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | saint-augustin
# Processing Record 39 of Set 12 | hurghada
# Processing Record 40 of Set 12 | agirish
# Processing Record 41 of Set 12 | clyde river
# Processing Record 42 of Set 12 | butembo
# Processing Record 43 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 12 | la massana
# Processing Record 45 of Set 12 | aksha
# Processing Record 46 of Set 12 | necochea
# Processing Record 47 of Set 12 | cunha
# Processing Record 48 of Set 12 | clarksburg
# Processing Record 49 of Set 12 | bubaque
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | pangai
# Processing Record 2 of Set 13 | coruripe
# Processing Record 3 of Set 13 | boueni
# Processing Record 4 of Set 13 | san carlos de bariloche
# Processing Record 5 of Set 13 | kailua
# Processing Record 6 of Set 13 | goundam
# Processing Record 7 of Set 13 | taoudenni
# Processing Record 8 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 13 | gilbues
# Processing Record 10 of Set 13 | kota kinabalu
# Processing Record 11 of Set 13 | tezu
# Processing Record 12 of Set 13 | cubuk
# Processing Record 13 of Set 13 | kalmunai
# Processing Record 14 of Set 13 | byron bay
# Processing Record 15 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 13 | uch
# Processing Record 17 of Set 13 | stawell
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 567

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='Challenge_Results/WeatherPy_challenge.csv', index_label='City_ID')

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# challenge objective 
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Ribeira Grande      PT  38.5167  -28.7000     72.59        83
# 1        Bredasdorp      ZA -34.5322   20.0403     53.28        93
# 2    Nuevo Progreso      MX  23.1667  -97.9500     91.60        63
# 3          Santa Fe      AR -31.6333  -60.7000     59.99        58
# 4          Luderitz      NA -26.6481   15.1594     55.90        73
# ..              ...     ...      ...       ...       ...       ...
# 558   San Cristobal      VE   7.7669  -72.2250     77.18        99
# 559          Nagato      JP  34.3833  131.2000     75.11        94
# 560       Wolfsburg      DE  52.4333   10.8000     66.99        77
# 561        Ust-Nera      RU  64.5667  143.2000     62.22        69
# 562          Kupang      ID -10.1667  123.5833     81.18        65
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0            91        3.15     overcast clouds           0.00              0
# 1            43        1.14    scattered clouds           0.00              0
# 2            58       10.45       broken clouds           0.00              0
# 3             8        1.01           clear sky           0.00              0
# 4             2        8.37           clear sky           0.00              0
# ..          ...         ...                 ...            ...            ...
# 558          47        3.09    scattered clouds           0.00              0
# 559         100        4.21          light rain           0.75              0
# 560          70        6.44          light rain           0.24              0
# 561          84        9.10          light rain           0.16              0
# 562          20       13.80          few clouds           0.00              0
#
# [563 rows x 11 columns]

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 8        Talnakh      RU  69.4865   88.3972     56.10        93          99
# 37        Narsaq      GL  60.9167  -46.0500     50.22        98          99
# 39       Qaanaaq      GL  77.4840  -69.3632     37.94        99         100
# 56     Mahebourg      MU -20.4081   57.7000     68.29        77          40
# 60        Fuyang      CN  32.9000  115.8167     74.82        90          98
# 84        Dikson      RU  73.5069   80.5464     45.52       100         100
# 91          Kabo      CF   7.6994   18.6290     70.59        96          76
# 92       Kavieng      PG  -2.5744  150.7967     83.89        73          97
# 109  Makhinjauri      GE  41.6739   41.6940     69.66        94          90
# 121         Bara      NG  10.3744   10.7288     73.44        92          98
#
#      Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 8         10.89                   light rain           0.32              0
# 37         4.59                moderate rain           1.11              0
# 39         4.92                   light rain           0.41              0
# 56        11.50                   light rain           0.31              0
# 60         5.17                   light rain           0.25              0
# 84        11.25                   light rain           0.33              0
# 91         2.42                   light rain           0.71              0
# 92        10.16                   light rain           0.41              0
# 109        3.44  light intensity shower rain           0.25              0
# 121        5.73                   light rain           0.69              0

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(10)
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
